# %% [markdown]
# ### Databricks Output Parameter
#
# ![](Images/82/82 Databricks Output Parameter.jpg)

# %% [markdown]
# ### ADF Collect Output Value
#
# ![](Images/82/82 ADF Collect Output Value.jpg)

# %% [markdown]
# ### Related with Azure
