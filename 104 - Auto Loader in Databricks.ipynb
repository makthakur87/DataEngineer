# %% [markdown]
# ### What is Auto Loader?
#
# ![](Images/104/104 Auto Loader.jpg)

# %% [markdown]
# ### Characterstics of Incremental Data Load
#
# ![](Images/104/104 Characterstics of Incremental Data Load.jpg)

# %% [markdown]
# ### Common Patterns of Incremental Data Loading
#
# ### Pattern 1
#
# ![](Images/104/104 Water Mark Method - Pattern 1.jpg)
#
# ### Pattern 2
#
# ![](Images/104/104 CheckPointing - Pattern 2.jpg)
#
# ### What is Best Solution?
#
# ![](Images/104/104 Best Solution.jpg)

# %% [markdown]
# ### What is AutoLoader?
#
# ![](Images/104/104 Auto Load.jpg)

# %% [markdown]
# ### Components of AuotLoader
#
# ![](Images/104/104 Components of AutoLoader.jpg)

# %% [markdown]
# ### Two Parts of AutoLoader
#
# ![](Images/104/104 Two Parts of AutoLoader.jpg)

# %% [markdown]
# ### File Detection Mode
#
# ![](Images/104/104 File Detection Mode.jpg)

# %% [markdown]
# ### Directory Listing Mode
#
# ![](Images/104/104 Directory Listing Mode.jpg)
#
# ![](Images/104/104 Directory Listing.jpg)

# %% [markdown]
# ### Comparison
#
# ![](Images/104/104 Comparison.jpg)

# %% [markdown]
# ### File Notification Mode
#
# ![](Images/104/104 File Notification Mode.jpg)
#
# ### Parameters
#
# ![](Images/104/104 Parameters.jpg)

# %% [markdown]
# ### Summary Architecture
#
# ![](Images/104/104 Summary Architecture.jpg)

# %% [markdown]
# ### Code Related to Azure
