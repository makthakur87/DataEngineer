# %% [markdown]
# ### Join Types
#
# ![](Images/70/70 Join Types.jpg)

# %% [markdown]
# ### SOrt Merge Join Phases
#
# ![](Images/70/70 Sort Merge Join Phases.jpg)

# %% [markdown]
# ### Example
#
# ![](Images/70/70 Example Raw Data.jpg)
#
# ![](Images/70/70 Example Dataframe.jpg)
#
# ![](Images/70/70 Example Shuffle Phase.jpg)
#
# ![](Images/70/70 Example Sorting Phase.jpg)
#
# ![](Images/70/70 Example Merge Phase.jpg)
#
# ![](Images/70/70 Example DAG.jpg)
#
# ![](Images/70/70 Example Explain Plan.jpg)
