# %% [markdown]
# ### History
#
# ![](Images/26 History.jpg)

# %% [markdown]
# ### Architecture of Spark Optimizer
#
# ![](Images/26 Architecture of Spark Optimizer.jpg)

# %% [markdown]
# ### AQE (Adaptive Query Execution) Features
#
# ![](Images/26 AQE Features.jpg)

# %% [markdown]
# ### Dynamically Coalescing Shuffle Partitions
#
# ![](Images/26 Dynamically Coalescing Shuffle Partitions.jpg)
#
# ![](Images/26 With AQE.jpg)

# %% [markdown]
# ### Dynamically Switching Join Strategies
#
# ![](Images/26 Dynamically Switching Join Strategies.jpg)

# %% [markdown]
# ### Dynamically Optimizing Skew Joins
#
# ![](Images/26 Skew Joins.jpg)
#
# ![](Images/26 Example.jpg)

# %% [markdown]
# ### Summary
#
# ![](Images/26 Summary.jpg)
