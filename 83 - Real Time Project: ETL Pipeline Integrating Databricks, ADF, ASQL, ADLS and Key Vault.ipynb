# %% [markdown]
# ### Architectural Components
#
# ![](Images/83/83 Architectural Components.jpg)

# %% [markdown]
# ### Architecture of Demo Project
#
# ![](Images/83/83 Architecture of Demo Project.jpg)

# %% [markdown]
# ### Related to Azure
