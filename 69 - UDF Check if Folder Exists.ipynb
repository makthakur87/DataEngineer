# %% [markdown]
# ### Lecture Related to Azure

# %%
def folderExists(path):
  try:
    dbutils.fs.ls(path)
    return True
  except Exception as err:
    if 'java.io.FileNotFoundException' in str(err):
      return False

# %%
# folder path which we need to check if exists or not
path = "mnt/adls_test/sales/2018"

if not folderExists(path):
    print("Folder does not exists")
    dbutils.fs.mkdirs(path)
else:
    print("Folder already does exists")
