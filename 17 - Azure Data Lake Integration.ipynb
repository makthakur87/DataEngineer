# %% [markdown]
# ### ADLS Intergraton with **Databricks**
# **Using a Service Principal**
#
# **Using Azure Active Directory credentials known as a credential passthrough**
#
# **Using ADLS access key directly**
#
# **Creating Mount Point using ADLS Access Key**
#
# covering only Step 3 and Step 4 in the demo
#
# ![](Images/17 ADLS Intergraton with Databricks.jpg)

# %% [markdown]
# ### **High Level Actions**
# **Step 1** - Create Azure Data Lake Storage
#
# **Step 2** - Create a Mount Point
#
# **Step 3** - Read Files from ADLS in Databricks
#
# ![](Images/17 High Level Actions.jpg)
