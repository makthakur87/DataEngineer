# %% [markdown]
# ### What is Expectation?
#
# ![](Images/108/108 What is Expectation.jpg)

# %% [markdown]
# ### Components of Expectation
#
# ![](Images/108/108 Components of Expectation.jpg)

# %% [markdown]
# ### Violation Action
#
# ![](Images/108/108 Violation Action.jpg)
