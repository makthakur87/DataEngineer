# %% [markdown]
# ### DBUtils Commands
#
# ![](/Workspace/Users/thakurr.mandeep@gmail.com/DataEngineer/Images/10 DBUtils Commands.jpg)

# %% [markdown]
# ### DBUtils Help
#
# ![](/Workspace/Users/thakurr.mandeep@gmail.com/DataEngineer/Images/10 DBUtils Help.jpg)

# %% [markdown]
# # **DBUtils fs Help**

# %%
dbutils.fs.help()

# %%
dbutils.fs.help('cp')

# %% [markdown]
# # **DBUtils Notebook Help**

# %%
dbutils.notebook.help()

# %% [markdown]
# # **DBUtils Widgets Help**

# %%
dbutils.widgets.help()

# %% [markdown]
# # **DBUtils Secrets Help**

# %%
dbutils.secrets.help()

# %% [markdown]
# # **DBUtils File System Commands**
#
# ![](Images/10 DBUtils Commands 1.jpg)

# %%
dbutils.fs.ls("/Volumes/workspace/default/mandy/baby_names/")

# %%
dbutils.fs.head("/Volumes/workspace/default/mandy/baby_names/Baby_Names_2007_2009.csv")

# %%
dbutils.fs.mkdirs("/Volumes/workspace/default/mandy/baby_name_test")

# %%
dbutils.fs.cp("/Volumes/workspace/default/mandy/baby_names/Baby_Names_2007_2009.csv", "/Volumes/workspace/default/mandy/baby_name_test")

# %%
dbutils.fs.mv("/Volumes/workspace/default/mandy/baby_names/Baby_Names_2010_2012.csv", "/Volumes/workspace/default/mandy/baby_name_test/")

# %%
dbutils.fs.put("/Volumes/workspace/default/mandy/baby_name_test/test.txt", "This is a test file")

# dbutils.fs.head("/Volumes/workspace/default/mandy/baby_name_test/test.txt")

# %%
dbutils.fs.rm("/Volumes/workspace/default/mandy/baby_name_test/Baby_Names_2010_2012.csv")

# %%
dbutils.fs.rm("/Volumes/workspace/default/mandy/baby_name_test", True)

# %% [markdown]
# # **DBUtils Notebook Commands**

# %%
dbutils.notebook.run("/Workspace/Users/thakurr.mandeep@gmail.com/10 - Training", 60)

# %% [markdown]
# # **Widgets**

# %%
# %run ./10_Training_Widget $Folder_Name="/Volumes/workspace/default/mandy/baby_names/" $File_Name="Baby_Names_2010_2012.csv"

# %%
dbutils.widgets.dropdown("Drop_down", "1", [str(x) for x in range(1, 10)])
dbutils.widgets.combobox("Combo_box", "1", [str(x) for x in range(1, 10)])
dbutils.widgets.multiselect("product", "Camera", ("Camera", "GPS", "Smartphone"))

# %%
dbutils.widgets.remove("Combo_box")

# %%
dbutils.widgets.removeAll()
