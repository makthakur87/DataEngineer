# %% [markdown]
# ### Procedural Approach
#
# ![](Images/106/106 Procedural Approach.jpg)
#
# ### Example
#
# ![](Images/106/106 Example.jpg)

# %% [markdown]
# ### Declrative Approach
#
# ![](Images/106/106 Declarative Approach.jpg)
