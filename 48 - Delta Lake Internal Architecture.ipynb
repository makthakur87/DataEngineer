# %% [markdown]
# ### WHat is Delta Lake?
#
# ![](Images/48/48 Delta Lake.jpg)

# %% [markdown]
# ### Transaction Logs
#
# ![](Images/48/48 Transaction Logs.jpg)

# %% [markdown]
# ### Create Delta Table

# %%
from delta.tables import *

DeltaTable.create(spark) \
  .tableName("workspace.default.delta_internal_demo") \
  .addColumn("emp_id", "INT") \
  .addColumn("emp_name", "STRING") \
  .addColumn("gender", "STRING") \
  .addColumn("salary", "INT") \
  .addColumn("dept", "STRING") \
  .property("description", "table created for demo purpose") \
  .execute()

# %%
# %sql
select * from delta_internal_demo;

# %%
# %sql
insert into delta_internal_demo values(100, 'Stephen', 'M', 2000, 'IT')

# %%
# %sql
insert into delta_internal_demo values(200, 'Phillip', 'M', 8000, 'HR');
insert into delta_internal_demo values(300, 'Lara', 'F', 6000, 'SALES');

# %%
# %sql
insert into delta_internal_demo values(100, 'Stephen', 'M', 2000, 'IT');
insert into delta_internal_demo values(200, 'Phillip', 'M', 8000, 'HR');
insert into delta_internal_demo values(300, 'Lara', 'F', 6000, 'SALES');

insert into delta_internal_demo values(100, 'Stephen', 'M', 2000, 'IT');
insert into delta_internal_demo values(200, 'Phillip', 'M', 8000, 'HR');
insert into delta_internal_demo values(300, 'Lara', 'F', 6000, 'SALES');

# %%
# %sql
select * from delta_internal_demo;

# %%
# %sql
delete from delta_internal_demo where emp_id = 100;
    
select * from delta_internal_demo;

# %% [markdown]
# ### How It Works
#
# ![](Images/48/48 How it Works.jpg)

# %%
# %sql
drop table delta_internal_demo
