# %% [markdown]
# ### **High Level Actions**
#
# ![](Images/20/20 High Level Actions.jpg)
#
# **Step 1** - Azure Key Vault setup
#
# **Step 2** - Databricks scoped credential setup
#
# **Step 3** - Retrieve keys from Azure key vault in Databricks

# %% [markdown]
# ### **Azure Key Vault Setup**
#
# **Step 1** - login to Azure Portal
#
# **Step 2** - Spin the service Azure key vault
#
# **Step 3** - Note down DNS name and resource ID
#
# **Step 4** - create a secret

# %% [markdown]
# ### **Databricks scoped credential setup**
#
# **step 1** - name the scoped credential
#
# **step 2** - input the DNS name and resource ID
#
# **Step 3** - create scoped credential
