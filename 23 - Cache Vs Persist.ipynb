# %% [markdown]
# ### What is Cache and Persist
# - Cache is programming mechanism which gives an option to store the data in-memeory across nodes
#
# - Persist is programming mechanism which gives an opton to store the data either in-memory or in disc across nodes
#
# ![](Images/23 Cache & Persist.jpg)

# %% [markdown]
# ### Eaxmple
#
# ![](Images/23 Cache & Persist Example.jpg)

# %% [markdown]
# ### Storage Level
#
# ![](Images/23 Storage Level.jpg)

# %% [markdown]
# ### Summary
#
# ![](Images/23 Summary.jpg)
