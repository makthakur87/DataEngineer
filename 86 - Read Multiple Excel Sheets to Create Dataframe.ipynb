# %% [markdown]
# ### Library Installation

# %%
# install this library in Maven Coordinates in the cluster
# com.crealytics.spark:spark-excel_2.12:0.13.5

# %%
# %fs
ls /Volumes/workspace/default/mandy/

# %% [markdown]
# ### Read Single Sheet of Excel

# %%
# Please ensure spark-excel library (to read Excel files into a Spark DataFrame) is installed on your cluster before running this code.
df = spark.read.format("com.crealytics.spark.excel").option("header", "true").option("inferSchema", "true").option("dataAddress", "sheet3!").load("/Volumes/workspace/default/mandy/excel_score_data.xlsx")
display(df)

# %% [markdown]
# ### Define Excel Location and Sheet Names

# %%
sheets = ["sheet1", "sheet2", "sheet3"]
path = "/Volumes/workspace/default/mandy/excel_score_data.xlsx"

# %% [markdown]
# ### UDF to Create Dataframe from Multiple Sheets and Perform Union

# %%
def createExcelDataFrame(path, sheets):
  firstSheet = sheets[0]
  df = spark.read.format("com.crealytics.spark.excel").option("header", "true").option("inferSchema", "true").option("dataAddress", f"{firstSheet}!").load(path)

  schema = df.schema

  for sheet in sheets[1:]:
    sheetDF = spark.read.format("com.crealytics.spark.excel").schema(schema).option("header", "true").option("dataAddress", f"{sheet}!").load(path)
    df = df.union(sheetDF)
  
  return df

# %% [markdown]
# ### Call UDF and Display Output Dataframe

# %%
outDF = createExcelDataFrame(path, sheets)
display(outDF)
