# %% [markdown]
# ### Window Functions
#
# ![](Images/67/67 Window Function.jpg)
#
# ![](Images/67/Window Function 1.jpg)

# %% [markdown]
# ### Window Functions - LEAD and LAG
#
# ![](Images/67/67 LEAD and LAG.jpg)

# %% [markdown]
# ### Create Dataframe

# %%
simpleData = (
  ("James", "Sales", 3000),
  ("Michael", "Sales", 4600),
  ("Robert", "Sales", 4100),
  ("Maria", "Finance", 3000),
  ("James", "Sales", 3000),
  ("Scott", "Finance", 3300),
  ("Jen", "Finance", 3900),
  ("Jeff", "Marketing", 3000),
  ("Kumar", "Marketing", 2000),
  ("Saif", "Sales", 4100)
  )

columns = ["employee_name", "department", "salary"]

df = spark.createDataFrame(data = simpleData, schema = columns)
df.show()

# %% [markdown]
# ### Window Definition

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

windowSpec = Window.partitionBy("department").orderBy("Salary")

# %% [markdown]
# ### LAG Window Function

# %%
from pyspark.sql.functions import lag
df.withColumn("lag", lag("salary", 1).over(windowSpec)).show()
df.withColumn("lag", lag("salary", 2).over(windowSpec)).show()

# %% [markdown]
# ### LEAD Window Function

# %%
from pyspark.sql.functions import lead
df.withColumn("lead", lead("salary", 1).over(windowSpec)).show()
df.withColumn("lead", lead("salary", 2).over(windowSpec)).show()
