# %% [markdown]
# ### Check If Source File Exists

# %%
ls /mnt/adls_test/sales

# %% [markdown]
# ### Create Input Dataframe

# %%
saleDF = spark.read.format("parquet").load("/mnt/adls_test/sales/salesdata.parquet")

# %% [markdown]
# ### Number of Records

# %%
print(saleDF.count())

# %% [markdown]
# ### Wide Transformation

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, lit

windowSpec = Window.partitionBy("SalesOrderLineKey").orderBy("SalesOrderLineKey")

outDF = saleDF.withColumn("row_number", row_number().over(windowSpec))
display(outDF)

# %% [markdown]
# ### Write Dataframe into Target Location As Is

# %%
outDF.write.format("csv").option("header", "true").option("sep", "|").save("/mnt/adls_test/sales/outputOriginal/")

# %%
ls /mnt/adls_test/sales/outputOriginal/

# %% [markdown]
# ### Convert to Single Partition and Write

# %%
outDF.coalesce(1).write.format("csv").option("header", "true").option("sep", "|").save("/mnt/adls_test/sales/outputSingleFile/")

# %%
ls /mnt/adls_test/sales/outputSingleFile/

# %% [markdown]
# ### Try Writing with Specific File Name

# %%
outDF.coalesce(1).write.format("csv").option("header", "true").option("sep", "|").save("/mnt/adls_test/sales/outputSingleFile/outputSingleFile.csv")

# %%
ls /mnt/adls_test/sales/outputSingleFile/

# %% [markdown]
# ### Solution: Convert to Panda Dataframe

# %%
pandaDf = outDF.toPandas()
print(pandaDf)

# %%
ls /mnt/adls_test/sales/outputSingleSpcificName/

# %% [markdown]
# ### Write Pandas Dataframe with Specific File Name

# %%
outName = 'salesOutput.csv'
outdir = '/dbfs/mnt/adls_test/sales/'
pandaDf.to_csv(outdir+outName, index=False)

# %%
head /mnt/adls_test/sales/outputSingleSpcificName/salesOutput.csv

# %% [markdown]
# ### End of Solution
