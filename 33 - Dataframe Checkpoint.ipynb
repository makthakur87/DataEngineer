# %% [markdown]
# ### What is Dataframe Checkpointing
#
# ![](Images/33/33 Dataframe Checkpointing.jpg)

# %% [markdown]
# ### Example
#
# ![](Images/33/33 Example.jpg)

# %% [markdown]
# ### Checkpoint vs Cache
#
# ![](Images/33/33 Checkpoint vs Cache.jpg)

# %% [markdown]
# ### Use Cases of Checkpoint Dataframe
#
# ![](Images/33/33 Use Cases of Checkpoint Dataframe.jpg)
