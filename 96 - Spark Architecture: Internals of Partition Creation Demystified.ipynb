# %% [markdown]
# ### Spark Partitions Mystery
#
# ![](Images/96/96 Spark Partitions Mystery.jpg)

# %% [markdown]
# ### How Spark Reader Access Data Files
#
# ![](Images/96/96 Spark Reader Accesses Data Files.jpg)

# %% [markdown]
# ### Worker Node Architecture
#
# ![](Images/96/96 Worker Node Architecture.jpg)

# %% [markdown]
# ### Files vs Executers
#
# ![](Images/96/96 Files vs Executers.jpg)

# %% [markdown]
# ### One File in Mulitple Executor
#
# ![](Images/96/96 One File in Multiple Executor.jpg)

# %% [markdown]
# ### InputFormat API
#
# ![](Images/96/96 InputFormat API.jpg)

# %% [markdown]
# ### Components of InputFormat API
#
# ![](Images/96/96 Components of InputFormat API.jpg)

# %% [markdown]
# ### FileInputFormat
#
# ![](Images/96/96 FileInputFormat.jpg)

# %% [markdown]
# ### InputSplit
#
# ![](Images/96/96 InputSplit.jpg)
#
# ![](Images/96/96 InputSplit Example.jpg)

# %% [markdown]
# ### Record Reader
#
# ![](Images/96/96 RecordReader.jpg)

# %% [markdown]
# ### Parameters Defining Partition Count
#
# ![](Images/96/96 Parameters Defining Partition Count.jpg)

# %% [markdown]
# ### Bytes Per Core
#
# ![](Images/96/96 BytePerCore.jpg)

# %% [markdown]
# ### Max Split Bytes
#
# ![](Images/96/96 MaxSplitBytes.jpg)
#
# ### Scenario
#
# ![](Images/96/96 Scenario.jpg)
#
# ### Calculate BytesPerCore
#
# ![](Images/96/96 Calculate BytesPerCore.jpg)
#
# ### Calculate MaxSplitBytes
#
# ![](Images/96/96 Calculate MaxSplitBytes.jpg)

# %% [markdown]
# ### Perform Input Split
#
# ![](Images/96/96 Perform InputSplit.jpg)
#
# ### Read Data Files to Create Physical Partition
#
# ![](Images/96/96 Read Data Files to Create Physical Partition.jpg)

# %% [markdown]
# ### Partition Packing - Scenario 1
#
# ![](Images/96/96 Partition Packing.jpg)
#
# ### Partition Packing - Scenario 2
#
# ![](Images/96/96 Partition Packing - Scenario 2.jpg)

# %% [markdown]
# ### Example - Scenario 1
#
# ![](Images/96/96 Example - Scenario 1.jpg)
#
# ### Example - Scenario 2
#
# ![](Images/96/96 Example - Scenario 2.jpg)
#
# ### Example - Scenario 3
#
# ![](Images/96/96 Example - Scenario 3.jpg)
