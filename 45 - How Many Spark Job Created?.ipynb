# %% [markdown]
# ### How Many JObs Created?
#
# ![](Images/45/45 How Many Jobs Created.jpg)
#
# ![](Images/45/45 Job Created.jpg)

# %% [markdown]
# ### Read CSV File without Any Option

# %%
df_no_option = spark.read.format('csv').load('/Volumes/workspace/default/mandy/baby_names/Baby_Names_2007_2009.csv')

# %%
display(df_no_option)

# %% [markdown]
# ### Read CSV File with Infer Schema True

# %%
df_infer_schema = spark.read.format('csv').option('inferSchema', True).load('/Volumes/workspace/default/mandy/baby_names/Baby_Names_2007_2009.csv')

# %%
display(df_infer_schema)

# %% [markdown]
# ### Read CSV File with Defind Schema

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
schema = StructType([
    StructField('Year', IntegerType(), False),
    StructField('FirstName', StringType(), True),
    StructField('County', StringType(), True),
    StructField('Sex', StringType(), True),
    StructField('Count', StringType(), True)     
])

# %%
df_defind_schema = spark.read.format('csv').schema(schema).load('/Volumes/workspace/default/mandy/baby_names/Baby_Names_2007_2009.csv')
