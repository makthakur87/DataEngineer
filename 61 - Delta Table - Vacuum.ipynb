# %%
# %sql
CREATE OR REPLACE TABLE scd2Demo(
  pk1 INT,
  pk2 STRING,
  dim1 INT,
  dim2 INT,
  dim3 INT,
  dim4 INT,
  active_status STRING,
  start_date TIMESTAMP,
  end_date TIMESTAMP
) USING DELTA

# %%
# %sql
insert into scd2Demo values (111, 'Unit1', 200, 500, 800, 400, 'Y', current_timestamp(), '9999-12-31');
insert into scd2Demo values (222, 'Unit2', 900, Null, 700, 100, 'Y', current_timestamp(), '9999-12-31');
insert into scd2Demo values (333, 'Unit3', 300, 900, 250, 650, 'Y', current_timestamp(), '9999-12-31');

# %%
# %sql
insert into scd2Demo values (444, 'Unit4', 200, 500, 800, 400, 'Y', current_timestamp(), '9999-12-31');
insert into scd2Demo values (555, 'Unit5', 900, Null, 700, 100, 'Y', current_timestamp(), '9999-12-31');
insert into scd2Demo values (666, 'Unit6', 300, 900, 250, 650, 'Y', current_timestamp(), '9999-12-31');

# %%
# %sql
select * from scd2demo

# %%
# %sql
delete from scd2demo where pk1 = 555

# %%
# %sql
select * from scd2demo

# %%
# %sql
update scd2demo set dim1 = 100 where pk1 = 666

# %%
# %sql
select * from scd2demo

# %%
# %sql
optimize scd2demo

# %%
# %sql
describe history scd2demo

# %%
# %sql
select * from scd2demo

# %%
ls workspace.default.scd2demo

# %%
# %sql
vacuum scd2demo dry run

# %%
# %sql
vacuum scd2demo retain 720 hours dry run

# %%
# %sql
set spark.datbricks.delta.retentionDurationCheck.enable = false

# %%
# %sql
vacuum scd2demo
