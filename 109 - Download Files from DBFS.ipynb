# %% [markdown]
# ### URL Construction for Community Edition
#
# ![](Images/109/109 URL Construction for Community Edition.jpg)

# %% [markdown]
# ### URL Construction for Standard Edition
#
# ![](Images/109/109 URL Construction for Standard Edition.jpg)
