# %% [markdown]
# ### On-Heap Memory
#
# ![](/Workspace/Users/thakurr.mandeep@gmail.com/DataEngineer/Images/On-Heap Memory.jpg)

# %% [markdown]
# ### On-Heap Memory
#
# ![](/Workspace/Users/thakurr.mandeep@gmail.com/DataEngineer/Images/On-Heap Memory 1.jpg)

# %% [markdown]
# ### Off-Heap Memory
#
# ![](/Workspace/Users/thakurr.mandeep@gmail.com/DataEngineer/Images/Off-Heap Memory.jpg)

# %% [markdown]
# ### On-Heap and Off-Heap Memory Summary
#
# ![](/Workspace/Users/thakurr.mandeep@gmail.com/DataEngineer/Images/On-Off-Heap Memory Summary.jpg)
