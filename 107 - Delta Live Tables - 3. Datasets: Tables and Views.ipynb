# %% [markdown]
# ### Delta Live Table
#
# ![](Images/107/107 Delta Live Table.jpg)

# %% [markdown]
# ### Streaming Table
#
# ![](Images/107/107 Streaming Table.jpg)

# %% [markdown]
# ### Materialized View
#
# ![](Images/107/107 Materialized View.jpg)

# %% [markdown]
# ### View
#
# ![](Images/107/107 View.jpg)

# %% [markdown]
# ### Spark SQL Syntax
#
# ![](Images/107/107 Spark SQL Syntax.jpg)

# %% [markdown]
# ### Pyspark SQL Syntax
#
# ![](Images/107/107 Pyspark SQL Syntax.jpg)

# %% [markdown]
# ### Summary
#
# ![](Images/107/107 Summary.jpg)
