# %% [markdown]
# ### What is Shuffling Parameter
#
# ![](Images/31/31 Shuffle.jpg)

# %% [markdown]
# ### Significance of Shuffling
#
# ![](Images/31/31 Significance of Shuffle.jpg)

# %% [markdown]
# ### Shuffling Parameter
#
# ![](Images/31/31 Shuffling Parameter.jpg)

# %% [markdown]
# ### How to Decide Shuffling Parameter
#
# ![](Images/31/31 How to Decide Shuffling Parameter.jpg)

# %% [markdown]
# ### Factors to Consider
#
# ![](Images/31/31 Factors to Consider.jpg)
