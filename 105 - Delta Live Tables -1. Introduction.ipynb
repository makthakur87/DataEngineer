# %% [markdown]
# ### Medallion Architecture
#
# ![](Images/105/105 Medallion Architecture.jpg)

# %% [markdown]
# ### Complexity of Medallion Architecture
#
# ![](Images/105/105 Complexity of Medallion Architecture.jpg)

# %% [markdown]
# ### Challenge with Current Solution Approach
#
# ![](Images/105/105 Challenge with Current Solution Approach.jpg)

# %% [markdown]
# ### Process of Developing Pipeline
#
# ![](Images/105/105 Process of Developing Pipeline.jpg)
#
# ### Where should We Focus??
#
# ![](Images/105/105 Where should We Focus.jpg)

# %% [markdown]
# ### What is Solution?
#
# ![](Images/105/105 What is Solution.jpg)
#
# ### What is Delta Live Table?
#
# ![](Images/105/105 What is Delta Live Table.jpg)
#
# ### Delta Live Table
#
# ![](Images/105/105 Delta Live Table.jpg)
#
# ### Development
#
# ![](Images/105/105 Development.jpg)
