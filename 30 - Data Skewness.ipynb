# %% [markdown]
# ### What is Data Skew
#
# ![](Images/30/30 Data Skew.jpg)

# %% [markdown]
# ### Partition - Even Sized
#
# ![](Images/30/30 Partition - Even Sized.jpg)

# %% [markdown]
# ### Partition - Uneven Sized
#
# ![](Images/30/30 Partition - Uneven Sized.jpg)

# %% [markdown]
# ### Data Skew Impact
#
# ![](Images/30/30 Data Skew Impact.jpg)

# %% [markdown]
# ### Data Skew Root Cause
#
# ![](Images/30/30 Data Skew Root Cause.jpg)

# %% [markdown]
# ### Execution Process
#
# ![](Images/30/30 Execution Process.jpg)

# %% [markdown]
# ### How to Handle Data Skew
#
# ![](Images/30/30 How to Handle Data Skew.jpg)

# %% [markdown]
# ### Salting
#
# ![](Images/30/30 Salting.jpg)

# %% [markdown]
# ### Skew Hint
#
# ![](Images/30/30 Skew Hint.jpg)

# %% [markdown]
# ### Broadcast Join
#
# ![](Images/30/30 Broadcast Variable.jpg)

# %% [markdown]
# ### Enable AQE
#
# ![](Images/30/30 Adaptive Query Optimizatoin - AQE.jpg)

# %% [markdown]
# ### Skew Optimized with AQE
#
# ![](Images/30/30 Adaptive Query Optimizatoin - AQE.jpg)
