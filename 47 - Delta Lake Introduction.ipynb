# %% [markdown]
# ### What is Delta Lake?
#
# ![](Images/47/47 Delta Lake.jpg)

# %% [markdown]
# ### Data Warehouse vs Data Lake vs Delta Lake
#
# ![](Images/47/47 Data Warehouse vs Data Lake vs Delta Lake.jpg)

# %% [markdown]
# ### Comparison
#
# ![](Images/47/47 Comparison.jpg)
