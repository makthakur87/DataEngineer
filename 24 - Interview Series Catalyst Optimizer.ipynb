# %% [markdown]
# ### What is Catalyst Optimizer
#
# ![](Images/24 Catalyst Optimizer.jpg)

# %% [markdown]
# ### Optimization Example
#
# ![](Images/24 Optimization Example.jpg)

# %% [markdown]
# ### Catalyst Optimizer Apply Optimization
#
# ![](Images/24 Optimization Area.jpg)

# %% [markdown]
# ![](Images/24.jpg)

# %% [markdown]
# ### RBO vs CBO
#
# ![](Images/24 RBO vs CBO.jpg)

# %% [markdown]
# ### Architecture of Catalyst Optimizer
#
# ![](Images/24 Architecture.jpg)
