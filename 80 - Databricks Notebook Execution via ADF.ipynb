# %% [markdown]
# ### Databricks Notebook Execution via ADF (Azure Data Factory)
#
# ![](Images/80/80 ADF.jpg)

# %% [markdown]
# ### ADF Trigger vs Databricks Workflow
#
# ![](Images/80/80 ADF Trigger vs Databricks Workflow.jpg)

# %% [markdown]
# ### ADF Components
#
# ![](Images/80/80 Components.jpg)

# %% [markdown]
# ### Related with Azure
