# %% [markdown]
# ### What is Autoscaling
#
# ![](Images/32/32 Autoscaling.jpg)

# %% [markdown]
# ### Types of Autoscaling
#
# ![](Images/32/32 Autoscale Types.jpg)

# %% [markdown]
# ### Optimized vs Standard
#
# ![](Images/32/32 Optimized vs Standard.jpg)
