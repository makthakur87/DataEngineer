# %% [markdown]
# ### What is Pandas?
#
# ![](Images/94/94 Pandas.jpg)

# %% [markdown]
# ### What is PySpark?
#
# ![](Images/94/94 PySpark.jpg)

# %% [markdown]
# ### Difference
#
# ![](Images/94/94 Difference Pandas vs PySpark.jpg)
