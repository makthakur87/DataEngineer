# %% [markdown]
# ### Secret Scope
#
# ![](Images/78/78 Secret Scope.jpg)

# %% [markdown]
# ### Types of Secret Scope
#
# ![](Images/78/78 Types of Secret Scope.jpg)

# %% [markdown]
# ### Secret Scope Syntax
#
# ![](Images/78/78 Secret Scope Syntax.jpg)

# %% [markdown]
# ### Related to Azure
